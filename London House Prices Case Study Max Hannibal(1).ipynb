# %%
import sys
# !{sys.executable} -m pip install pandas
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 9.3 MB/s eta 0:00:00 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 9.1 MB/s eta 0:00:00a 0:00:01
# ...

# %%
import numpy as np
import pandas as pd

# %%
pip install matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 7.2 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 6.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 8.5 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import sys 
# !{sys.executable} -m pip install openpyxl

# %%
import openpyxl
import openpyxl.reader.excel
# !{sys.executable} -m pip install xlrd==1.2.0
url_LondonHousePrices ='https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls'
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col=None)

# %%
print(properties.head())
# Out:
#   Unnamed: 0 City of London Barking & Dagenham       Barnet       Bexley  \
# 0        NaT      E09000001          E09000002    E09000003    E09000004
# 1 1995-01-01    91448.98487         50460.2266  93284.51832  64958.09036
# 2 1995-02-01    82202.77314        51085.77983  93190.16963  64787.92069
# 3 1995-03-01    79120.70256        51268.96956  92247.52435  64367.49344
# 4 1995-04-01    77101.20804        53133.50526  90762.87492  64277.66881
#
#          Brent      Bromley       Camden      Croydon       Ealing  ...  \
# 0    E09000005    E09000006    E09000007    E09000008    E09000009  ...
# 1  71306.56698  81671.47692  120932.8881  69158.16225  79885.89069  ...
# 2  72022.26197  81657.55944  119508.8622  68951.09542  80897.06551  ...
# 3  72015.76274  81449.31143  120282.2131  68712.44341  81379.86288  ...
# 4  72965.63094  81124.41227   120097.899  68610.04641  82188.90498  ...
#
#     NORTH WEST YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND  \
# ...

# %%
properties_T = properties.transpose()
print(properties_T.head())
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001          91448.98487          82202.77314
# Barking & Dagenham  E09000002           50460.2266          51085.77983
# Barnet              E09000003          93284.51832          93190.16963
# Bexley              E09000004          64958.09036          64787.92069
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London              79120.70256          77101.20804
# Barking & Dagenham          51268.96956          53133.50526
# Barnet                      92247.52435          90762.87492
# Bexley                      64367.49344          64277.66881
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
print(properties_T.index)
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
properties_T = properties_T.reset_index()
print(properties_T.index)
# Out:
# RangeIndex(start=0, stop=49, step=1)

# %%
print(properties_T.head())
# Out:
#                 index          0                    1                    2  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
#                      6                    7                    8  ...  \
# ...

# %%
print(properties_T.columns)
# Out:
# Index(['index',       0,       1,       2,       3,       4,       5,       6,
#              7,       8,
#        ...
#            344,     345,     346,     347,     348,     349,     350,     351,
#            352,     353],
#       dtype='object', length=355)

# %%
print(properties_T.iloc[[0]])
# Out:
#         index    0                    1                    2  \
# 0  Unnamed: 0  NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
#
#                    344                  345                  346  \
# 0  2023-08-01 00:00:00  2023-09-01 00:00:00  2023-10-01 00:00:00
#
#                    347                  348                  349  \
# 0  2023-11-01 00:00:00  2023-12-01 00:00:00  2024-01-01 00:00:00
#
#                    350                  351                  352  \
# 0  2024-02-01 00:00:00  2024-03-01 00:00:00  2024-04-01 00:00:00
#
#                    353
# 0  2024-05-01 00:00:00
#
# [1 rows x 355 columns]

# %%
properties_T.columns = properties_T.iloc[0]
print(properties_T.head())
# Out:
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0          Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1      City of London  E09000001          91448.98487          82202.77314
# 2  Barking & Dagenham  E09000002           50460.2266          51085.77983
# 3              Barnet  E09000003          93284.51832          93190.16963
# 4              Bexley  E09000004          64958.09036          64787.92069
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1          79120.70256          77101.20804          84409.14932
# 2          51268.96956          53133.50526          53042.24852
# 3          92247.52435          90762.87492          90258.00033
# 4          64367.49344          64277.66881          63997.13588
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# ...

# %%
properties_T = properties_T.drop(0)
print(properties_T.head())
# Out:
# 0          Unnamed: 0        NaT 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %%
properties_T = properties_T.rename(columns = {'Unnamed: 0':'London_Borough', pd.NaT: 'ID'})
print(properties_T.head())
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001         91448.98487         82202.77314
# 2  Barking & Dagenham  E09000002          50460.2266         51085.77983
# 3              Barnet  E09000003         93284.51832         93190.16963
# 4              Bexley  E09000004         64958.09036         64787.92069
# 5               Brent  E09000005         71306.56698         72022.26197
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1         79120.70256         77101.20804         84409.14932
# 2         51268.96956         53133.50526         53042.24852
# 3         92247.52435         90762.87492         90258.00033
# 4         64367.49344         64277.66881         63997.13588
# 5         72015.76274         72965.63094         73704.04743
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1         94900.51244         110128.0423         112329.4376  ...
# ...

# %%
print(properties_T.columns)
# Out:
# Index([   'London_Borough',                'ID', 1995-01-01 00:00:00,
#        1995-02-01 00:00:00, 1995-03-01 00:00:00, 1995-04-01 00:00:00,
#        1995-05-01 00:00:00, 1995-06-01 00:00:00, 1995-07-01 00:00:00,
#        1995-08-01 00:00:00,
#        ...
#        2023-08-01 00:00:00, 2023-09-01 00:00:00, 2023-10-01 00:00:00,
#        2023-11-01 00:00:00, 2023-12-01 00:00:00, 2024-01-01 00:00:00,
#        2024-02-01 00:00:00, 2024-03-01 00:00:00, 2024-04-01 00:00:00,
#        2024-05-01 00:00:00],
#       dtype='object', name=0, length=355)

# %%
clean_properties = pd.melt(properties_T, id_vars= ['London_Borough', 'ID'])
print(clean_properties.head())
# Out:
#        London_Borough         ID                    0        value
# 0      City of London  E09000001  1995-01-01 00:00:00  91448.98487
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.2266
# 2              Barnet  E09000003  1995-01-01 00:00:00  93284.51832
# 3              Bexley  E09000004  1995-01-01 00:00:00  64958.09036
# 4               Brent  E09000005  1995-01-01 00:00:00  71306.56698

# %%
clean_properties = clean_properties.rename(columns = {0: 'Month', 'value': 'Average_price'})
print(clean_properties.head())
# Out:
#        London_Borough         ID                Month Average_price
# 0      City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00    50460.2266
# 2              Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3              Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4               Brent  E09000005  1995-01-01 00:00:00   71306.56698

# %%
print(clean_properties.dtypes)
# Out:
# London_Borough    object
# ID                object
# Month             object
# Average_price     object
# dtype: object

# %%
clean_properties['Average_price'] = pd.to_numeric(clean_properties['Average_price'])
print(clean_properties.dtypes)
# Out:
# London_Borough     object
# ID                 object
# Month              object
# Average_price     float64
# dtype: object

# %%
print(clean_properties.count())
# Out:
# London_Borough    16944
# ID                15885
# Month             16944
# Average_price     15885
# dtype: int64

# %%
print(clean_properties['London_Borough'].unique())
# Out:
# ['City of London' 'Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley'
#  'Camden' 'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney'
#  'Hammersmith & Fulham' 'Haringey' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Islington' 'Kensington & Chelsea' 'Kingston upon Thames'
#  'Lambeth' 'Lewisham' 'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames'
#  'Southwark' 'Sutton' 'Tower Hamlets' 'Waltham Forest' 'Wandsworth'
#  'Westminster' 'Unnamed: 34' 'Inner London' 'Outer London' 'Unnamed: 37'
#  'NORTH EAST' 'NORTH WEST' 'YORKS & THE HUMBER' 'EAST MIDLANDS'
#  'WEST MIDLANDS' 'EAST OF ENGLAND' 'LONDON' 'SOUTH EAST' 'SOUTH WEST'
#  'Unnamed: 47' 'England']

# %%
print(clean_properties[clean_properties['London_Borough'] == 'Unnamed: 34'].head())
# Out:
#     London_Borough   ID                Month  Average_price
# 33     Unnamed: 34  NaN  1995-01-01 00:00:00            NaN
# 81     Unnamed: 34  NaN  1995-02-01 00:00:00            NaN
# 129    Unnamed: 34  NaN  1995-03-01 00:00:00            NaN
# 177    Unnamed: 34  NaN  1995-04-01 00:00:00            NaN
# 225    Unnamed: 34  NaN  1995-05-01 00:00:00            NaN

# %%
print(clean_properties[clean_properties['London_Borough'] == 'Unnamed: 37'].head())
# Out:
#     London_Borough   ID                Month  Average_price
# 36     Unnamed: 37  NaN  1995-01-01 00:00:00            NaN
# 84     Unnamed: 37  NaN  1995-02-01 00:00:00            NaN
# 132    Unnamed: 37  NaN  1995-03-01 00:00:00            NaN
# 180    Unnamed: 37  NaN  1995-04-01 00:00:00            NaN
# 228    Unnamed: 37  NaN  1995-05-01 00:00:00            NaN

# %%
print(clean_properties[clean_properties['London_Borough'] == 'Unnamed: 47'].head())
# Out:
#     London_Borough   ID                Month  Average_price
# 46     Unnamed: 47  NaN  1995-01-01 00:00:00            NaN
# 94     Unnamed: 47  NaN  1995-02-01 00:00:00            NaN
# 142    Unnamed: 47  NaN  1995-03-01 00:00:00            NaN
# 190    Unnamed: 47  NaN  1995-04-01 00:00:00            NaN
# 238    Unnamed: 47  NaN  1995-05-01 00:00:00            NaN

# %%
clean_properties.drop(clean_properties[clean_properties['London_Borough'] == 'Unnamed: 34'].index, axis = 0, inplace = True)
clean_properties.drop(clean_properties[clean_properties['London_Borough'] == 'Unnamed: 37'].index, axis = 0, inplace = True)
clean_properties.drop(clean_properties[clean_properties['London_Borough'] == 'Unnamed: 47'].index, axis = 0, inplace = True)

# %%
print(clean_properties['London_Borough'].unique())
# Out:
# ['City of London' 'Barking & Dagenham' 'Barnet' 'Bexley' 'Brent' 'Bromley'
#  'Camden' 'Croydon' 'Ealing' 'Enfield' 'Greenwich' 'Hackney'
#  'Hammersmith & Fulham' 'Haringey' 'Harrow' 'Havering' 'Hillingdon'
#  'Hounslow' 'Islington' 'Kensington & Chelsea' 'Kingston upon Thames'
#  'Lambeth' 'Lewisham' 'Merton' 'Newham' 'Redbridge' 'Richmond upon Thames'
#  'Southwark' 'Sutton' 'Tower Hamlets' 'Waltham Forest' 'Wandsworth'
#  'Westminster' 'Inner London' 'Outer London' 'NORTH EAST' 'NORTH WEST'
#  'YORKS & THE HUMBER' 'EAST MIDLANDS' 'WEST MIDLANDS' 'EAST OF ENGLAND'
#  'LONDON' 'SOUTH EAST' 'SOUTH WEST' 'England']

# %%
print(clean_properties[clean_properties['ID'].isna()])
# Out:
# Empty DataFrame
# Columns: [London_Borough, ID, 0, value]
# Index: []

# %%
print(clean_properties.head(48))
# Out:
#           London_Borough         ID                    0        value
# 0         City of London  E09000001  1995-01-01 00:00:00  91448.98487
# 1     Barking & Dagenham  E09000002  1995-01-01 00:00:00   50460.2266
# 2                 Barnet  E09000003  1995-01-01 00:00:00  93284.51832
# 3                 Bexley  E09000004  1995-01-01 00:00:00  64958.09036
# 4                  Brent  E09000005  1995-01-01 00:00:00  71306.56698
# 5                Bromley  E09000006  1995-01-01 00:00:00  81671.47692
# 6                 Camden  E09000007  1995-01-01 00:00:00  120932.8881
# 7                Croydon  E09000008  1995-01-01 00:00:00  69158.16225
# 8                 Ealing  E09000009  1995-01-01 00:00:00  79885.89069
# 9                Enfield  E09000010  1995-01-01 00:00:00  72514.69096
# 10             Greenwich  E09000011  1995-01-01 00:00:00  62300.10169
# 11               Hackney  E09000012  1995-01-01 00:00:00  61296.52637
# ...

# %%
NaNFreeDF1 = clean_properties[clean_properties['Average_price'].notna()]
NaNFreeDF1.head(48)
# Out:
#           London_Borough         ID                Month Average_price
# 0         City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1     Barking & Dagenham  E09000002  1995-01-01 00:00:00    50460.2266
# 2                 Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3                 Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4                  Brent  E09000005  1995-01-01 00:00:00   71306.56698
# 5                Bromley  E09000006  1995-01-01 00:00:00   81671.47692
# 6                 Camden  E09000007  1995-01-01 00:00:00   120932.8881
# 7                Croydon  E09000008  1995-01-01 00:00:00   69158.16225
# 8                 Ealing  E09000009  1995-01-01 00:00:00   79885.89069
# 9                Enfield  E09000010  1995-01-01 00:00:00   72514.69096
# 10             Greenwich  E09000011  1995-01-01 00:00:00   62300.10169
# 11               Hackney  E09000012  1995-01-01 00:00:00   61296.52637
# ...

# %%
NaNFreeDF1.count()
# Out:
# London_Borough    15885
# ID                15885
# Month             15885
# Average_price     15885
# dtype: int64

# %%
NaNFreeDF2 = clean_properties.dropna()
NaNFreeDF2.head(48)
# Out:
#           London_Borough         ID                Month Average_price
# 0         City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1     Barking & Dagenham  E09000002  1995-01-01 00:00:00    50460.2266
# 2                 Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3                 Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4                  Brent  E09000005  1995-01-01 00:00:00   71306.56698
# 5                Bromley  E09000006  1995-01-01 00:00:00   81671.47692
# 6                 Camden  E09000007  1995-01-01 00:00:00   120932.8881
# 7                Croydon  E09000008  1995-01-01 00:00:00   69158.16225
# 8                 Ealing  E09000009  1995-01-01 00:00:00   79885.89069
# 9                Enfield  E09000010  1995-01-01 00:00:00   72514.69096
# 10             Greenwich  E09000011  1995-01-01 00:00:00   62300.10169
# 11               Hackney  E09000012  1995-01-01 00:00:00   61296.52637
# ...

# %%
NaNFreeDF2.count()
NaNFreeDF2['London_Borough'].unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %%
print(clean_properties.shape)
print(NaNFreeDF1.shape)
print(NaNFreeDF2.shape)
# Out:
# (16944, 4)
# (15885, 4)
# (15885, 4)

# %%
nonBoroughs = ['Inner London', 'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER', 'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON', 'SOUTH EAST', 'SOUTH WEST', 'England']

# %%
NaNFreeDF2[NaNFreeDF2.London_Borough.isin(nonBoroughs)]
# Out:
#            London_Borough         ID                Month Average_price
# 34           Inner London  E13000001  1995-01-01 00:00:00    78251.9765
# 35           Outer London  E13000002  1995-01-01 00:00:00   72958.79836
# 37             NORTH EAST  E12000001  1995-01-01 00:00:00   42076.35411
# 38             NORTH WEST  E12000002  1995-01-01 00:00:00   43958.48001
# 39     YORKS & THE HUMBER  E12000003  1995-01-01 00:00:00   44803.42878
# ...                   ...        ...                  ...           ...
# 16938     EAST OF ENGLAND  E12000006  2024-05-01 00:00:00        337757
# 16939              LONDON  E12000007  2024-05-01 00:00:00        523376
# 16940          SOUTH EAST  E12000008  2024-05-01 00:00:00        375693
# 16941          SOUTH WEST  E12000009  2024-05-01 00:00:00        318223
# 16943             England  E92000001  2024-05-01 00:00:00        302393
#
# [4236 rows x 4 columns]

# %%
NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]
# Out:
#            London_Borough         ID                Month Average_price
# 0          City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1      Barking & Dagenham  E09000002  1995-01-01 00:00:00    50460.2266
# 2                  Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3                  Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4                   Brent  E09000005  1995-01-01 00:00:00   71306.56698
# ...                   ...        ...                  ...           ...
# 16924              Sutton  E09000029  2024-05-01 00:00:00        433257
# 16925       Tower Hamlets  E09000030  2024-05-01 00:00:00        445436
# 16926      Waltham Forest  E09000031  2024-05-01 00:00:00        498286
# 16927          Wandsworth  E09000032  2024-05-01 00:00:00        611595
# 16928         Westminster  E09000033  2024-05-01 00:00:00        932585
#
# [11649 rows x 4 columns]

# %%
NaNFreeDF2 = NaNFreeDF2[~NaNFreeDF2.London_Borough.isin(nonBoroughs)]

# %%
NaNFreeDF2.head()
# Out:
#        London_Borough         ID                Month Average_price
# 0      City of London  E09000001  1995-01-01 00:00:00   91448.98487
# 1  Barking & Dagenham  E09000002  1995-01-01 00:00:00    50460.2266
# 2              Barnet  E09000003  1995-01-01 00:00:00   93284.51832
# 3              Bexley  E09000004  1995-01-01 00:00:00   64958.09036
# 4               Brent  E09000005  1995-01-01 00:00:00   71306.56698

# %%
df = NaNFreeDF2

# %%
df.head()
df.dtypes
# Out:
# London_Borough    object
# ID                object
# Month             object
# Average_price     object
# dtype: object

# %%
camden_prices = df[df['London_Borough'] == 'Camden']

# %%
ax = camden_prices.plot(kind ='line', x = 'Month', y='Average_price')
ax.set_ylabel('Price')
# Out:
# /Users/maxhannibal/Desktop/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7588: FutureWarning: Dtype inference on a pandas object (Series, Index, ExtensionArray) is deprecated. The Index constructor will keep the original dtype in the future. Call `infer_objects` on the result to get the old behavior.
#   return Index(sequences[0], name=names)
# Text(0, 0.5, 'Price')

# %%
df['Year'] = df['Month'].apply(lambda t: t.year)
df.tail()
# Out:
#        London_Borough         ID                Month Average_price  Year
# 16924          Sutton  E09000029  2024-05-01 00:00:00        433257  2024
# 16925   Tower Hamlets  E09000030  2024-05-01 00:00:00        445436  2024
# 16926  Waltham Forest  E09000031  2024-05-01 00:00:00        498286  2024
# 16927      Wandsworth  E09000032  2024-05-01 00:00:00        611595  2024
# 16928     Westminster  E09000033  2024-05-01 00:00:00        932585  2024

# %%
dfg = df.groupby(by=['London_Borough', 'Year', 'Average_price']).mean(numeric_only = True)
dfg.sample(10)
# Out:
# Empty DataFrame
# Columns: []
# Index: [(Haringey, 2000, 143565.9994), (Newham, 2023, 406503.0), (Merton, 2015, 489855.2742), (Hackney, 2004, 219015.8934), (Havering, 2008, 243974.6809), (Bexley, 2023, 398394.0), (Enfield, 2014, 276980.4296), (Barking & Dagenham, 1995, 50945.18535), (Waltham Forest, 2017, 437935.1388), (Lewisham, 2017, 416507.5731)]

# %%
dfg = dfg.reset_index(drop = True)
dfg.head()
# Out:
#    level_0  index      London_Borough  Year  Average_price
# 0        0      0  Barking & Dagenham  1995    50460.22660
# 1        1      1  Barking & Dagenham  1995    50848.67787
# 2        2      2  Barking & Dagenham  1995    50945.18535
# 3        3      3  Barking & Dagenham  1995    51085.77983
# 4        4      4  Barking & Dagenham  1995    51268.96956

# %%
def create_price_ratio(d):
    y1998 = (d['Average_price'][d['Year']==1998]).sum().astype(float)
    y2018 = (d['Average_price'][d['Year']==2018]).sum().astype(float)
    ratio = [y2018/y1998]
    return ratio
create_price_ratio(dfg[dfg['London_Borough']=='Barking & Dagenham'])
# Out:
# [np.float64(4.89661861291754)]

# %%
final = {}
for b in dfg['London_Borough'].unique():
    borough = dfg[dfg['London_Borough'] == b]
    final[b] = create_price_ratio(borough)
print(final)
# Out:
# {'Barking & Dagenham': [np.float64(4.89661861291754)], 'Barnet': [np.float64(4.358195917538043)], 'Bexley': [np.float64(4.248977046127876)], 'Brent': [np.float64(4.894554497139286)], 'Bromley': [np.float64(4.0947846853338765)], 'Camden': [np.float64(4.935353408884261)], 'City of London': [np.float64(5.30162037758761)], 'Croydon': [np.float64(4.201100280024766)], 'Ealing': [np.float64(4.311450902121834)], 'Enfield': [np.float64(4.263471583495811)], 'Greenwich': [np.float64(4.763036347329193)], 'Hackney': [np.float64(6.198285561008663)], 'Hammersmith & Fulham': [np.float64(4.137798101936229)], 'Haringey': [np.float64(5.134624964136042)], 'Harrow': [np.float64(4.0591964329643195)], 'Havering': [np.float64(4.325230371335309)], 'Hillingdon': [np.float64(4.2002730803844575)], 'Hounslow': [np.float64(3.9764091061433287)], 'Islington': [np.float64(4.844048012802297)], 'Kensington & Chelsea': [np.float64(5.082465066092462)], 'Kingston upon Thames': [np.float64(4.270549521484271)], 'Lambeth': 
# ...

# %%
df_ratios = pd.DataFrame(final)
df_ratios.head()
# Out:
#    Barking & Dagenham    Barnet    Bexley     Brent   Bromley    Camden  \
# 0            4.896619  4.358196  4.248977  4.894554  4.094785  4.935353
#
#    City of London  Croydon    Ealing   Enfield  ...    Merton   Newham  \
# 0         5.30162   4.2011  4.311451  4.263472  ...  4.741273  5.30539
#
#    Redbridge  Richmond upon Thames  Southwark    Sutton  Tower Hamlets  \
# 0   4.471182              4.005162   5.516485  4.118523       4.626701
#
#    Waltham Forest  Wandsworth  Westminster
# 0        5.834756    4.757709     5.353565
#
# [1 rows x 33 columns]

# %%
df_ratios_T = df_ratios.T
df_ratios = df_ratios_T.reset_index()
df_ratios.head()
# Out:
#                 index         0
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
df_ratios.rename(columns={'index':'Borough', 0:'2018'}, inplace=True) 
df_ratios.head()
# Out:
#               Borough      2018
# 0  Barking & Dagenham  4.896619
# 1              Barnet  4.358196
# 2              Bexley  4.248977
# 3               Brent  4.894554
# 4             Bromley  4.094785

# %%
top15 = df_ratios.sort_values(by='2018',ascending=False).head(15)
print(top15)
# Out:
#                  Borough      2018
# 11               Hackney  6.198286
# 30        Waltham Forest  5.834756
# 27             Southwark  5.516485
# 22              Lewisham  5.449221
# 32           Westminster  5.353565
# 24                Newham  5.305390
# 6         City of London  5.301620
# 13              Haringey  5.134625
# 19  Kensington & Chelsea  5.082465
# 21               Lambeth  4.957751
# 5                 Camden  4.935353
# 0     Barking & Dagenham  4.896619
# 3                  Brent  4.894554
# 18             Islington  4.844048
# 10             Greenwich  4.763036

# %%
ax = top15[['Borough','2018']].plot(kind='bar')
ax.set_xticklabels(top15.Borough)
# Out:
# [Text(0, 0, 'Hackney'),
#  Text(1, 0, 'Waltham Forest'),
#  Text(2, 0, 'Southwark'),
#  Text(3, 0, 'Lewisham'),
#  Text(4, 0, 'Westminster'),
#  Text(5, 0, 'Newham'),
#  Text(6, 0, 'City of London'),
#  Text(7, 0, 'Haringey'),
#  Text(8, 0, 'Kensington & Chelsea'),
#  Text(9, 0, 'Lambeth'),
#  Text(10, 0, 'Camden'),
#  Text(11, 0, 'Barking & Dagenham'),
#  Text(12, 0, 'Brent'),
#  Text(13, 0, 'Islington'),
#  Text(14, 0, 'Greenwich')]
